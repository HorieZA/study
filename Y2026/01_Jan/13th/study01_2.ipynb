# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %%
print('신씨가 소리질렀다. "도둑이야".')
# Out:
# 신씨가 소리질렀다. "도둑이야".

# %%
print("C:\\Windows")
# Out:
# C:\Windows

# %%
print("안녕하세요.\n만나서\t\t반갑습니다.")
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %%
print("오늘은","일요일")
# Out:
# 오늘은 일요일

# %%
print("naver","kakao","sk","samsung",sep=";")
# Out:
# naver;kakao;sk;samsung

# %%
print("naver","kakao","sk","samsung",sep="/")
# Out:
# naver/kakao/sk/samsung

# %%
print("first", end=""); print("second")
# Out:
# firstsecond

# %%
print(5/3)
# Out:
# 1.6666666666666667

# %%
삼성전자 = 50000
총평가금액 = 삼성전자 * 10
print(총평가금액)
# Out:
# 500000

# %%
시가총액 = 298000000000000
현재가 = 50000
PER = 15.79
print(시가총액, type(시가총액))
print(현재가, type(현재가))
print(PER,type(PER))
# Out:
# 298000000000000 <class 'int'>
# 50000 <class 'int'>
# 15.79 <class 'float'>

# %%
s = "hello"
t = "python"
print(s+"!", t)
# Out:
# hello! python

# %%
print(2 + 2 * 3)
# Out:
# 8

# %%
a = 128
print (type(a))
a = "132"
print (type(a))
# Out:
# <class 'int'>
# <class 'str'>

# %%
num_str = "720"
num_str = int(num_str)
print(num_str, type(num_str))
# Out:
# 720 <class 'int'>

# %%
num = str(100)
print(num, type(num))
# Out:
# 100 <class 'str'>

# %%
key = float("15.79")
print(key, type(key))
# Out:
# 15.79 <class 'float'>

# %%
year = int("2020")
year = year + 3
print(year, type(year))
# Out:
# 2023 <class 'int'>

# %%
월가격 = 48584
총액 = 월가격 * 36
print(f"에이컨 총액 : {총액}", type(총액))
# Out:
# 에이컨 총액 : 1749024 <class 'int'>

# %%
letters = 'python'
print(letters[0], letters[2])
# Out:
# p t

# %%
license_plate = "24가 2210"
print(license_plate[-4:])
# Out:
# 2210

# %%
string = "홀짝홀짝홀짝"
print(string[::2])
# Out:
# 홀홀홀
